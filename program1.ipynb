# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45c8/Python_lab/blob/main/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(2+3)
# Out:
# 5

# %%
print (int(input()))
# Out:
# 5
# 5

# %%
print(8-5)
# Out:
# 3

# %%
print(8*6)
# Out:
# 48

# %%
print(90/5)
# Out:
# 18.0

# %%
a=4
print(type(a))
# Out:
# <class 'int'>

# %%
s='world'
print(type(s))
# Out:
# <class 'str'>

# %%
a = 5
b = 6
print(a,b)
# Out:
# 5 6

# %%
a = input()
# Out:
# 7

# %%
b = input()
# Out:
# 3

# %%
c = float(input())
# Out:
# 7.09

# %%
a = 6
b = 4
print(a//b)
# Out:
# 1

# %%
a = str(input())
# Out:
# 6

# %%
a
# Out:
# '6'

# %%
c = str (input())
# Out:
# python

# %%
c
# Out:
# 'python'

# %%
a = 2**3

# %%
a
# Out:
# 8
