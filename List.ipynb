# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45c8/Python_lab/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Indexing and slicing
l = ["sathvika",90,18,96]
print(l)
# Out:
# ['sathvika', 90, 18, 96]

# %%
print(l[0])
# Out:
# sathvika

# %%
print(l[0:3])
# Out:
# ['sathvika', 90, 18]

# %%
print(l[1:4])
# Out:
# [90, 18, 96]

# %%
print(l[::-1])
# Out:
# [96, 18, 90, 'sathvika']

# %%
print(l[-1:-4:-2])
# Out:
# [96, 90]

# %%
L1 = [1,2,3,4,'y',"sathvika"]
L2 = [5,6,7,8,'p',"python"]
print(L1[4])       # indexing
print(L2[::-1])    # slicing
print(L1+L2)      # concetenation
print(L1*2)       # repetation
print(5 in L2)    # membership
print(5 in L1)
print(5 not in L1)
for i in L2:      # iteration (loop)
  print(i)
# Out:
# y
# ['python', 'p', 8, 7, 6, 5]
# [1, 2, 3, 4, 'y', 'sathvika', 5, 6, 7, 8, 'p', 'python']
# [1, 2, 3, 4, 'y', 'sathvika', 1, 2, 3, 4, 'y', 'sathvika']
# True
# False
# True
# 5
# 6
# 7
# 8
# p
# python

# %%
#predefined functions
M1 = [2,3,9,64,70,82]
print(sum(M1))
print(min(M1))
print(max(M1))
print(len(M1))
# Out:
# 230
# 2
# 82
# 6
